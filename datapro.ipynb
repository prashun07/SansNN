# %%
import pandas as pd

# %%
d1=pd.read_csv("./Data/bible.csv")

# %%
d1.head()
# Out:
#     data_id  book_id  chapter  verse  \
# 0  40001001       40        1      1
# 1  40001002       40        1      2
# 2  40001003       40        1      3
# 3  40001004       40        1      4
# 4  40001005       40        1      5
#
#                                             sanskrit  \
# 0  \u0907\u092c\u094d\u0930\u093e\u0939\u0940\u09...
# 1  \u0907\u092c\u094d\u0930\u093e\u0939\u0940\u09...
# 2  \u0924\u0938\u094d\u092e\u093e\u0926\u094d \u0...
# 3  \u0924\u0938\u094d\u092f \u092a\u0941\u0924\u0...
# 4  \u0924\u0938\u094d\u092e\u093e\u0926\u094d \u0...
#
#                                              english
# 0  The book of the generation of Jesus Christ, th...
# 1  Abraham begat Isaac; and Isaac begat Jacob; an...
# 2  And Judas begat Phares and Zara of Thamar; and...
# 3  And Aram begat Aminadab; and Aminadab begat Na...
# 4  And Salmon begat Booz of Rachab; and Booz bega...

# %%
d2=pd.read_csv("./Data/decoded-Gita-data.csv")

# %%
d2.head()
# Out:
#       id                                                 SA  \
# 0  c:1v1  \u0927\u0943\u0924\u0930\u093e\u0937\u094d\u09...
# 1  c:1v2  \u0938\u091e\u094d\u091c\u092f \u0909\u0935\u0...
# 2  c:1v3  \u092a\u0936\u094d\u092f\u0948\u0924\u093e\u09...
# 3  c:1v4  \u0905\u0924\u094d\u0930 \u0936\u0942\u0930\u0...
# 4  c:1v5  \u0905\u0924\u094d\u0930 \u0936\u0942\u0930\u0...
#
#                                                   EN
# 0  Dhritarashtra said: O Sanjay, after gathering ...
# 1  Sanjay said: On observing the Pandava army sta...
# 2  Duryodhan said: Respected teacher! Behold the ...
# 3  Behold in their ranks are many powerful warrio...
# 4  Behold in their ranks are many powerful warrio...

# %%
d2.rename(columns={'SA':'sanskrit','EN':'english'},inplace=True)

# %%
d3=pd.concat([d1, d2])
d3.head()
# Out:
#       data_id  book_id  chapter  verse  \
# 0  40001001.0     40.0      1.0    1.0
# 1  40001002.0     40.0      1.0    2.0
# 2  40001003.0     40.0      1.0    3.0
# 3  40001004.0     40.0      1.0    4.0
# 4  40001005.0     40.0      1.0    5.0
#
#                                             sanskrit  \
# 0  \u0907\u092c\u094d\u0930\u093e\u0939\u0940\u09...
# 1  \u0907\u092c\u094d\u0930\u093e\u0939\u0940\u09...
# 2  \u0924\u0938\u094d\u092e\u093e\u0926\u094d \u0...
# 3  \u0924\u0938\u094d\u092f \u092a\u0941\u0924\u0...
# 4  \u0924\u0938\u094d\u092e\u093e\u0926\u094d \u0...
#
#                                              english   id
# 0  The book of the generation of Jesus Christ, th...  NaN
# 1  Abraham begat Isaac; and Isaac begat Jacob; an...  NaN
# 2  And Judas begat Phares and Zara of Thamar; and...  NaN
# 3  And Aram begat Aminadab; and Aminadab begat Na...  NaN
# 4  And Salmon begat Booz of Rachab; and Booz bega...  NaN

# %%
d4=d3.drop(['data_id','book_id','chapter','verse','id'],axis=1)

# %%
d4.head()
# Out:
#                                             sanskrit  \
# 0  \u0907\u092c\u094d\u0930\u093e\u0939\u0940\u09...
# 1  \u0907\u092c\u094d\u0930\u093e\u0939\u0940\u09...
# 2  \u0924\u0938\u094d\u092e\u093e\u0926\u094d \u0...
# 3  \u0924\u0938\u094d\u092f \u092a\u0941\u0924\u0...
# 4  \u0924\u0938\u094d\u092e\u093e\u0926\u094d \u0...
#
#                                              english
# 0  The book of the generation of Jesus Christ, th...
# 1  Abraham begat Isaac; and Isaac begat Jacob; an...
# 2  And Judas begat Phares and Zara of Thamar; and...
# 3  And Aram begat Aminadab; and Aminadab begat Na...
# 4  And Salmon begat Booz of Rachab; and Booz bega...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-38ff8a04567d> in <module>
# ----> 1 df.to_csv(r'C:\Users\Prashum\Desktop\sanskritproject\SanTran-master\SanTran-master')
#
# NameError: name 'df' is not defined
